# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings ('ignore')

# %matplotlib inline

# %%
df = pd.read_csv('objects/ES5min_04-24-2023.csv', parse_dates=True)
df['Date']=df['Date'] + " " + df['Time']
df['Date']=pd.to_datetime(df['Date'])
df.set_index(df['Date'], inplace = True)
df.dropna(inplace=True)
df.head()
# Out:
#                                    Date             Time    Open     Last  \
# Date
# 2021-11-09 16:15:00 2021-11-09 16:15:00  16:15:00.000000  4746.0  4745.25
# 2021-11-09 16:20:00 2021-11-09 16:20:00  16:20:00.000000  4745.0  4745.00
# 2021-11-09 16:25:00 2021-11-09 16:25:00  16:25:00.000000  4745.0  4744.25
# 2021-11-09 16:30:00 2021-11-09 16:30:00  16:30:00.000000  4744.5  4745.00
# 2021-11-09 16:35:00 2021-11-09 16:35:00  16:35:00.000000  4745.0  4745.75
#
#                         High      Low  Volume  # of Trades  Bid Volume  \
# Date
# 2021-11-09 16:15:00  4746.50  4745.00    1448          679         923
# 2021-11-09 16:20:00  4746.00  4745.00     767          373         356
# 2021-11-09 16:25:00  4745.25  4744.25     793          339         516
# 2021-11-09 16:30:00  4745.00  4744.25     494          305         230
# 2021-11-09 16:35:00  4746.00  4745.00     591          296         282
#
#                      Ask Volume  ...  IB High  IB Mid  IB High Ext 3  \
# Date                             ...
# 2021-11-09 16:15:00         525  ...        0       0              0
# 2021-11-09 16:20:00         411  ...        0       0              0
# 2021-11-09 16:25:00         277  ...        0       0              0
# 2021-11-09 16:30:00         264  ...        0       0              0
# 2021-11-09 16:35:00         309  ...        0       0              0
#
#                      IB High Ext 2  IB Low Ext 1  IB Low Ext 2  US POC  \
# Date
# 2021-11-09 16:15:00              0             0             0     0.0
# 2021-11-09 16:20:00              0             0             0     0.0
# 2021-11-09 16:25:00              0             0             0     0.0
# 2021-11-09 16:30:00              0             0             0     0.0
# 2021-11-09 16:35:00              0             0             0     0.0
#
#                      US VWAP  ON POC  GLOBEX VWAP.1
# Date
# 2021-11-09 16:15:00      0.0  4732.0            0.0
# 2021-11-09 16:20:00      0.0  4732.0            0.0
# 2021-11-09 16:25:00      0.0  4732.0            0.0
# 2021-11-09 16:30:00      0.0  4732.0            0.0
# 2021-11-09 16:35:00      0.0  4732.0            0.0
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Open', 'Last', 'High', 'Low', 'Volume', '# of Trades',
#        'Bid Volume', 'Ask Volume', 'Delta', 'GLOBEX VWAP', 'IB High Ext 1',
#        'IB High', 'IB Mid', 'IB High Ext 3', 'IB High Ext 2', 'IB Low Ext 1',
#        'IB Low Ext 2', 'US POC', 'US VWAP', 'ON POC', 'GLOBEX VWAP.1'],
#       dtype='object')

# %%
df = df.between_time(start_time='9:30:00', end_time='11:30:00', include_start='true', include_end='true' )
            "Delta": "sum"
        })
locs = df31.index.indexer_at_time('9:30:00')
df32 = df31.iloc[locs]
df32.head(20)
df32.dropna(inplace=True)
df32
# Out:
#                         Open     High      Low     Last  Volume  Delta
# Date
# 2021-11-10 09:30:00  4730.50  4747.00  4728.00  4745.75  163542   2606
# 2021-11-11 09:30:00  4726.75  4727.50  4717.00  4724.50  128001  -2405
# 2021-11-12 09:30:00  4726.00  4726.50  4715.75  4717.50  116900  -6878
# 2021-11-15 09:30:00  4761.25  4762.75  4751.00  4760.25  136268  -3726
# 2021-11-16 09:30:00  4746.25  4764.75  4745.50  4760.00  153369   4137
# ...                      ...      ...      ...      ...     ...    ...
# 2023-04-18 09:30:00  4193.50  4194.75  4182.25  4184.00  155525  -3187
# 2023-04-19 09:30:00  4158.50  4163.25  4157.75  4159.00  154121  -1357
# 2023-04-20 09:30:00  4146.25  4157.25  4145.00  4150.50  159847  -2305
# 2023-04-21 09:30:00  4155.75  4156.50  4142.50  4143.00  193882  -6816
# 2023-04-24 09:30:00  4153.50  4163.25  4152.75  4160.75  137368   4506
#
# [374 rows x 6 columns]

# %% [markdown]
# #### Does delta in the first 5 min indicate price action in subseqent periods. What is delta in the first 5 min period. What is the high of following 30min period?

# %%
df['Delta_EMA-30'] = df['Delta'].rolling(60).mean()

# %%
locs = df.index.indexer_at_time('9:30:00')
df = df.iloc[locs]
df.head(20)
df.dropna(inplace=True)
df['30min_high']=df32['High']
df['30min_low']=df32['Low']
df['sub_high_range'] = df['30min_high']-df['Last'] 
df['sub_low_range'] = df['30min_low']-df['Last']
df.columns
# Out:
# Index(['Date', 'Time', 'Open', 'Last', 'High', 'Low', 'Volume', '# of Trades',
#        'Bid Volume', 'Ask Volume', 'Delta', 'Delta_EMA-30', '30min_high',
#        'sub_periods_range', 'sub_high_range', '30min_low', 'sub_low_range'],
#       dtype='object')

# %%
d = df[['Delta', 'Delta_EMA-30', 'sub_high_range', 'sub_low_range',"Volume", '# of Trades']]
d['average_trades']=d['# of Trades'].rolling(30).mean()
d['average_volume']=d['Volume'].rolling(30).mean()

# %%
# d =d.loc[(d['Delta']<d['Delta_EMA-30']) & (d['# of Trades']<d['average_trades']) & d['Volume']>d['average_volume']]
d =d.loc[(d['Delta']<d['Delta_EMA-30']) & (d['# of Trades']<d['average_trades'])]
d
# Out:
# Empty DataFrame
# Columns: [Delta, Delta_EMA-30, sub_high_range, sub_low_range, Volume, # of Trades, average_trades, average_volume]
# Index: []

# %%
d['average']=(d['sub_high_range'] + d['sub_low_range']).rolling(60).mean()

# %%
d['sub_low_range'].plot(figsize=(12,6))
d['sub_high_range'].plot()
d['average'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
